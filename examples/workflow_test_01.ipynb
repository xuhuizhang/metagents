# %%
from examples import RiskWorkflow

# %%
question_01 = '''
分析一下2BOD中HIGHAR和非HIGHAR不同个两组，分别计算approve rate, 以及fpd30的rate
'''

# %%
response = RiskWorkflow().data_explore(question_01)
# Out:
# load old vectorstore
# ++++++++++ 下面分析一下可能需要的业务逻辑
#
# 业务: General
# 业务术语: 通过率（Approve Rate）
# 背景介绍: 被通过的offer或者contract的申请所占的份额
# 涉及数据库字段: flag_approve
# **********
# 业务: CFCS
# 业务术语: 2BOD
# 背景介绍: 在aided loan(al) 的数据库中，如果segment_risk_lvl1=XCL则表示2BOD 流程。
# 涉及数据库字段: segment_risk_lvl1
# **********
# 业务: General
# 业务术语: 逾期天数DPD
# 背景介绍: 逾期天数，计算方法为从应还款日期起至实际还款日期止的天数。例如FPD10表示该客户首次逾期达到或超过10天的发生在贷款的第一期还款。SPD30意味着在第二期首次出现逾期大于等于30天，第一期没有逾期或逾期小于30。
# 涉及数据库字段: fpd30，spd30
# **********
# 业务: CFCS
# 业务术语: HIGHAR
# 背景介绍: HIGHAR是一个放开通过率AR的group，策略在2022年8月份上线。如果name_strategy_prelim1列中的字符有HIGHAR的标记则表示放开了通过率，如果没有标记表示没有放开通过率。
# 涉及数据库字段: name_strategy_prelim1
# **********
# 业务: CFCS
# 业务术语: 1BOD
# 背景介绍: 在aided loan(al) 的数据库中，如果segment_risk_lvl1=POS则表示1BOD 流程。
# 涉及数据库字段: segment_risk_lvl1
# ```python
# variable = [
#     'flag_approve, 表示申请是否被通过的标志',
#     'segment_risk_lvl1, 表示风险等级，XCL表示2BOD流程，POS表示1BOD流程',
#     'fpd30, 表示首次逾期达到或超过30天的标志',
#     'spd30, 表示在第二期首次出现逾期大于等于30天的标志',
# ...
